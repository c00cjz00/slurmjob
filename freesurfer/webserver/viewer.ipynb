# %%
pip install nibabel matplotlib
# Out:
# ...
#      |████████████████████████████████| 10.3 MB 2.3 MB/s            ███                 | 4.8 MB 2.3 MB/s eta 0:00:03
# ...
#      |████████████████████████████████| 1.2 MB 88.5 MB/s
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nibabel as nib
import matplotlib.pyplot as plt

img = nib.load('webserver/02322379.nii')
img_data = img.get_fdata()
print(img_data.shape)  #獲得資料shape資訊：（長，寬，維度-切片數量）
# Out:
# (512, 512, 56)
# 56

# %%
def show_slices(slices):
    fig, axes = plt.subplots(1, len(slices))
    for i, slice in enumerate(slices):
        axes[i].imshow(slice.T, cmap="gray", origin="lower")
        #axes[i].imshow(slice.T, cmap="gray")

        
slice_0 = img_data[52, :, :]
slice_1 = img_data[:, 13, :]
slice_2 = img_data[:, :, 14]
show_slices([slice_0, slice_1, slice_2])

# %%
#一張圖的標題名
plt.title("Brain Slices")
#三張圖的標題名
plt.suptitle("Brain Slices")
plt.show()

# %%
import nibabel as nib
import matplotlib.pyplot as plt

#從github下載裡面自帶的資料
img = nib.load('webserver/02322379.nii')
img_data = img.get_fdata()
img_data.shape  #獲得資料shape資訊：（長，寬，維度-切片數量）

'''
print(img_data.shape)
#(57, 67, 56)
print(img_data.shape[3])  #獲取總共的圖片張數
'''

def show_slices(slices):
    fig, axes = plt.subplots(1, len(slices))
    for i, slice in enumerate(slices):
        axes[i].imshow(slice.T, cmap="gray", origin="lower")
        #axes[i].imshow(slice.T, cmap="gray")

slice_0 = img_data[52, :, :]
slice_1 = img_data[:, 13, :]
slice_2 = img_data[:, :, 14]
show_slices([slice_0, slice_1, slice_2])

# %%
#檢視和顯示nii.gz檔案，並顯示圖片

from matplotlib import pylab as plt
import nibabel as nib

filename = 'webserver/02322379.nii'
img = nib.load(filename)

#方法一
img_data = img.get_fdata()
img_data.shape  #獲得資料shape資訊：（長，寬，維度-切片數量）
#print(img_data.shape)   #(57, 67, 56)
#print(img_data.shape[2])

#方法二
width, height, queue = img.dataobj.shape
#print(img.dataobj.shape[2])  #queue=56,56張圖片


'''
num = 1
#讀取0,10,20,30,40,50
for i in range(0, queue, 10):
    #獲取6張
    img_arr = img.dataobj[:, :, i]
    #5行4列
    plt.subplot(5, 4, num)
    plt.imshow(img_arr, cmap='gray')
    num += 1
'''

#每一張圖片全部顯示出來
num = 1

for i in range(queue):
    #獲取6張
    img_arr = img.dataobj[:, :, i]
    #9行7列，就是9×7=56=queue
    plt.subplot(9, 7, num)
    #plt.imshow(img_arr, cmap='gray')  #灰圖顯示
    plt.imshow(img_arr)  #彩圖顯示
    num += 1

plt.show()
